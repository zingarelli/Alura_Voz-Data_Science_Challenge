# %% [markdown]
# <a href="https://colab.research.google.com/github/zingarelli/alura-challenges-data-science-2022/blob/main/Semana-2/Alura_Challenges_%7C_Data_Science_2022_Semana_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de *Churn Rate* | Alura Voz
#
# Este notebook é uma [continuação do trabalho feito anteriormente](https://github.com/zingarelli/alura-challenges-data-science-2022/tree/main/Semana-1), cujo objetivo é auxiliar a empresa Alura Voz a reduzir o *Churn Rate* de clientes, isto é, a taxa de evasão de clientes (aqueles que cancelam o plano de Telefone/Internet/Vídeo).

# %% [markdown]
# ## Resumo da Semana 1
#
# No primeiro projeto, foi feito o tratamento da base de dados fornecida pela Alura Voz, que contém informações sobre seus clientes e os tipos de planos e valores de suas assinaturas, dentre outros dados relevantes. A [base está disponível online](https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json), bem como o [dicionário de dados](https://github.com/sthemonica/alura-voz/blob/main/dicionario.md), que contém uma breve explicação de cada coluna que compõe a base.
#
# Houve também uma adaptação das colunas e conteúdo da base para o português (anteriormente estavam em inglês), bem como a criação de uma nova coluna, trazendo informação sobre o gasto diário aproximado de cada cliente.
#
# Devido a todo o tratamento feito nos dados, nesta segunda etapa do projeto será trabalhado um [arquivo CSV](https://raw.githubusercontent.com/zingarelli/alura-challenges-data-science-2022/main/Semana-1/analise_semana_1.csv) que contém a base já limpa e formatada.

# %% [markdown]
# ## Semana 2 - Visualizações
# O foco nesta semana é analisar graficamente os dados, com foco maior na variável Churn (que agora se chama "cancelou_plano"). Procurar encontrar relações e tendências entre as variáveis, bem como explorar a distribuição dos dados para tentar, visualmente, encontrar perfis de clientes que optaram sair do plano.
#
# Para encontrar estas relações, vou tentar assumir algumas suposições. Não vou, no entanto, fazer teste de hipóteses ou abordagens do tipo, por não ter conhecimento nessa parte.

# %% [markdown]
# # Configurações iniciais
#
# Importação das bibliotecas necessárias e alteração em configurações do Colab para melhor visualização das saídas

# %%
import pandas as pd

# import para as bibliotecas de visualização
import matplotlib.pyplot as plt
import seaborn as sns 
# utilizando a biblioteca Plotly, como indicada pela empresa
# import plotly.express as px # acabou não dando tempo de testar :(

pd.set_option('display.max_columns', 22)

# %% [markdown]
# # Carregamento da Base de Dados
#
# A base de dados será carregada de um arquivo CSV, com os dados já tratados e formatados.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/zingarelli/alura-challenges-data-science-2022/main/Semana-1/analise_semana_1.csv')
df.head()
# Out:
#    cliente_ID cancelou_plano  genero  maior_65_anos  \
# 0  0002-ORFBO            Nao  Mulher              0
# 1  0003-MKNFE            Nao   Homem              0
# 2  0004-TLHLJ            Sim   Homem              0
# 3  0011-IGKFF            Sim   Homem              1
# 4  0013-EXCHZ            Sim  Mulher              1
#
#   possui_companheiro_companheira possui_dependentes  meses_contrato  \
# 0                            Sim                Sim               9
# 1                            Nao                Nao               9
# 2                            Nao                Nao               4
# 3                            Sim                Nao              13
# 4                            Sim                Nao               3
#
#   assina_telefone multiplas_linhas_telefonicas tipo_assinatura_internet  \
# 0             Sim                          Nao                     Cabo
# 1             Sim                          Sim                     Cabo
# 2             Sim                          Nao                    Fibra
# 3             Sim                          Nao                    Fibra
# 4             Sim                          Nao                    Fibra
#
#   adicional_seguranca_online adicional_backup_online  \
# 0                        Nao                     Sim
# 1                        Nao                     Nao
# 2                        Nao                     Nao
# 3                        Nao                     Sim
# 4                        Nao                     Nao
#
#   adicional_protecao_dispositivo adicional_suporte_VIP assina_TV_cabo  \
# 0                            Nao                   Sim            Sim
# 1                            Nao                   Nao            Nao
# 2                            Sim                   Nao            Nao
# 3                            Sim                   Nao            Sim
# 4                            Nao                   Sim            Sim
#
#   assina_streaming_filmes plano_contratado fatura_online     forma_pagamento  \
# 0                     Nao           Um ano           Sim  Cheque por Correio
# 1                     Sim           Mensal           Nao  Cheque por Correio
# 2                     Nao           Mensal           Sim   Cheque eletronico
# 3                     Sim           Mensal           Sim   Cheque eletronico
# 4                     Nao           Mensal           Sim  Cheque por Correio
#
#    gasto_diario  gasto_mensal  gasto_total
# 0          2.19          65.6       593.30
# 1          2.00          59.9       542.40
# 2          2.46          73.9       280.85
# 3          3.27          98.0      1237.85
# 4          2.80          83.9       267.40

# %%
# algumas informações básicas da base
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cliente_ID                      7043 non-null   object
#  1   cancelou_plano                  7043 non-null   object
#  2   genero                          7043 non-null   object
#  3   maior_65_anos                   7043 non-null   int64
#  4   possui_companheiro_companheira  7043 non-null   object
#  5   possui_dependentes              7043 non-null   object
#  6   meses_contrato                  7043 non-null   int64
#  7   assina_telefone                 7043 non-null   object
#  8   multiplas_linhas_telefonicas    7043 non-null   object
#  9   tipo_assinatura_internet        7043 non-null   object
#  10  adicional_seguranca_online      7043 non-null   object
#  11  adicional_backup_online         7043 non-null   object
#  12  adicional_protecao_dispositivo  7043 non-null   object
#  13  adicional_suporte_VIP           7043 non-null   object
#  14  assina_TV_cabo                  7043 non-null   object
#  15  assina_streaming_filmes         7043 non-null   object
#  16  plano_contratado                7043 non-null   object
#  17  fatura_online                   7043 non-null   object
#  18  forma_pagamento                 7043 non-null   object
#  19  gasto_diario                    7043 non-null   float64
#  20  gasto_mensal                    7043 non-null   float64
#  21  gasto_total                     7043 non-null   float64
# dtypes: float64(3), int64(2), object(17)
# memory usage: 1.2+ MB

# %% [markdown]
# # Análise da variável `cancelou_plano` (Churn)
#
# Na adaptação para o português, a variável `Churn` foi renomeada para `cancelou_plano`. Ela é uma variável categórica e dicotômica, contendo somente respostas Sim e Nao.
#
# Esta variável é nosso *target*, é aquilo que a Alura Voz busca reduzir. Futuramente no projeto, a intenção é verificar quais outras variáveis podem influenciar na intenção de um cliente cancelar ou não o plano.

# %%
# armazenando os dados em uma variável chamada churn
churn = df['cancelou_plano']

churn.value_counts()
# Out:
# Nao    5174
# Sim    1869
# Name: cancelou_plano, dtype: int64

# %%
# separando entre clientes que estão ativos e aqueles que cancelaram o plano (former_customer)
# lembrando que o "Sim" significa que o cliente cancelou o plano
active_customer = (churn == 'Nao').sum()
former_customer = (churn == 'Sim').sum()

print(f'Planos ativos: {active_customer}, {round(active_customer/len(churn)*100, 2)}% do total')
print(f'Planos cancelados: {former_customer}, {round(former_customer/len(churn)*100, 2)}% do total')
# Out:
# Planos ativos: 5174, 73.46% do total
# Planos cancelados: 1869, 26.54% do total

# %% [markdown]
# Pouco mais de um quarto da base de clientes cancelou o plano.
#
# Por carregar somente dois valores, podemos utilizar `churn` em um gráfico de pizza para facilitar a visualização das proporções.

# %%
# utilizando o pyplot
# startangle=90 faz com que a divisão comece a partir das 12h (imaginando um relógio)
plt.pie(
    churn.value_counts(), 
    labels=['Planos ativos', 'Planos Cancelados'], 
    startangle=90,
)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe95cc1ea50>,
#   <matplotlib.patches.Wedge at 0x7fe95cc1ee90>],
#  [Text(-0.8144539368428058, -0.7393678277834755, 'Planos ativos'),
#   Text(0.8144540060674139, 0.7393677515287918, 'Planos Cancelados')])

# %% [markdown]
# # Churn e relacionamento com outras variáveis
#
# Irei verificar graficamente se há algum tipo de relação do Churn com as outras variáveis da base. Por exemplo, comparar Churn com os valores mensais e totais gastos por cada cliente, e verificar se há alguma relação ou tendência entre essas variáveis.
#
# Uma suposição minha é que um dos motivos para clientes cancelarem o plano seja o preço, então esse será o primeiro objeto de análise.
#
# Outra suposição é que a quantidade de meses de contrato também pode influenciar a decisão por encerrar o plano (por exemplo, clientes com contrato de longa data podem possuir alguma afinidade/fidelidade ao plano e optar por mantê-lo).
#
# Novamente, são apenas suposições para guiar a visualização dos dados. Não irei fazer nada estatisticamente formal para testá-las.

# %% [markdown]
# ## Churn X Gastos
#
# Irei utilizar a biblioteca Seaborn para criar um gráfico de dispersão (scatterplot) categórico, comparando os gastos totais de cada cliente, divididos entre os que cancelaram o plano ou não. Minha intenção é observar se há uma concentração de clientes que cancelaram o plano dentro de algum intervalo de gastos.

# %%
# o catplot possibilita cruzar dados categóricos com numéricos por meio de 
# diferentes gráficos de dispersão. O padrão é o stripplot 
sns.catplot(x='cancelou_plano', y='gasto_total', data=df)

# %% [markdown]
# O gasto total não pareceu ser uma boa escolha, pois ele é muito abrangente. Cada cliente tem um gasto total diferente, baseado no número de meses com o plano e nas diferente opções de "extras" que podem ser adicionados ao plano.
#
# Irei então fazer a comparação com os gastos mensais:

# %%
sns.catplot(x='cancelou_plano', y='gasto_mensal', data=df)

# %% [markdown]
# Comparando com os gastos mensais, a visualização no gráfico parece ser mais relevante. É possível observar que, dentre os clientes que cancelaram o plano, há uma concentração na faixa dos que pagam entre 70 e 110 dólares (ou reais? Não sei).
#
# Podemos alterar o tipo de representação gráfica para `violin`, que auxilia a visualizar melhor onde os dados estão mais concentrados.

# %%
# kind é o parâmetro que altera entre as diferentes opções de scatterplot
sns.catplot(x='cancelou_plano', y='gasto_mensal', kind='violin', data=df)

# %% [markdown]
# Visualmente, é possível ver também uma grande concentração de planos com mensalidades mais baixas dentre aqueles que estão com o plano ativo.

# %% [markdown]
# ### Churn X Mensalidade X Gênero
# Vou adicionar uma terceira variável para verificar se o comportamento é parecido para homens e mulheres

# %%
# hue irá atribuir uma cor diferente para homens e mulheres
# split irá manter ambos os gêneros dentro de um mesmo violino, facilitando a comparação
sns.catplot(x='cancelou_plano', y='gasto_mensal', hue='genero', kind='violin', split=True, data=df)

# %% [markdown]
# Graficamente, é possível visualizar que, dentre os clientes que **cancelaram** seu plano, a quantidade de **mulheres** é **maior** na faixa dos planos mensais **entre 70 e 90 dólares**.
#
# É possível também observar algo interessante entre os que não cancelaram o plano: a distribuição por gênero parece ser muito semelhante (quase simétrico), independente da faixa de gastos mensais.

# %% [markdown]
# ### Churn X Mensalidade X Idade
# Posso também verificar como se distribuem as pessoas maiores de 65 dentro dessa comparação entre mensalidade e churn.
#
# No projeto anterior, optei por manter os valores da variável `maior_65_anos` sem alteração (e talvez agora comece a me arrepender...). Ela possui os valores 0 e 1, sendo que 1 significa que o cliente tem idade igual ou maior que 65 anos, e 0 caso contrário.

# %%
# TO DO: alterar a legenda via seaborn/matplotlib
sns.catplot(x='cancelou_plano', y='gasto_mensal', hue='maior_65_anos', kind='violin', split=True, data=df)

# %% [markdown]
# Nesta comparação, é possível verificar que há uma concentração maior de clientes que **cancelaram** o plano e que possuem idade **igual ou maior que 65 anos**, dentro da faixa dos que pagam **entre 70 e 100 dólares** mensais.
#
# É interessante também notar que, dentre os que possuem planos ativos e gastam mensalmente em média 20 dólares, há uma grande concentração de pessoas abaixo de 65 anos. Isso vai se invertendo conforme o gasto mensal com o plano vai aumentando. Infelizmente, a base de dados não possui informações mais estratificadas da idade para poder analisar esse fenômeno mais a fundo. Eu chutaria que os que pagam menos sejam os mais jovens, que talvez possuem menos recursos financeiros.

# %% [markdown]
# ### **Conclusão**
# Graficamente, parece que os clientes que **cancelaram** seus planos tinham gastos mensais na faixa de **70 a 110 dólares**, com uma concentração ligeiramente maior por volta de 80 dólares. Dentro dessa faixa, há uma quantidade maior de clientes **mulheres** e uma concentração relevante de pessoas com **idade maior ou igual a 65 anos**.

# %% [markdown]
# ## Churn X Fidelidade
# Nesta seção, irei comparar o churn rate com a quantidade de meses que o contrato do cliente está ativo, que eu vou denominar "fidelidade". Vou verificar se visualmente é possível observar alguma tendência ou padrão de perda de clientes baseado no tempo de fidelidade.

# %%
# visualizando a base de clientes por meses de contrato ativo (histograma)
# binwidth controla o intervalo de meses considerado para agrupar os valores
# no caso, conta a frequência de 5 a 5 meses
sns.displot(data=df, x='meses_contrato', binwidth=5)

# %% [markdown]
# Neste primeiro gráfico, de histograma da quantidade de clientes por meses de contrato, já é possível observar dois fatos interessantes:
#
# 1. Existe uma quantidade muito grande de clientes novos (0-5 meses);
# 2. Existe uma quantidade também muito grande de clientes antigos (mais de 5 anos de contrato, ou acima de 60 meses), o que pode indicar uma alta fidelidade à empresa ou seu plano de voz/internet.

# %%
# verificando a quantidade de clientes mais novos e mais antigos
total_customers = len(df)
total_customers_5_months = len(df[df['meses_contrato'] <= 5])
total_customers_5_years = len(df[df['meses_contrato'] > 60])

# calculando a proporção de clientes
perc_customers_5_months = round(total_customers_5_months/total_customers*100, 2)
perc_customers_5_years = round(total_customers_5_years/total_customers*100, 2)

print(f'Total de clientes: {total_customers}')
print(f'Total de clientes novos (0 a 5 meses): {total_customers_5_months}, {perc_customers_5_months}%')
print(f'Total de clientes fiéis (acima 5 anos): {total_customers_5_years}, {perc_customers_5_years}%')
# Out:
# Total de clientes: 7043
# Total de clientes novos (0 a 5 meses): 1371, 19.47%
# Total de clientes fiéis (acima 5 anos): 1407, 19.98%

# %% [markdown]
# Baseado neste histograma, irei verificar como  fica a distribuição do churn para comparar as duas variáveis (churn e fidelidade)

# %%
# col possibilita a divisão dos dados de "cancelou_plano", plotando gráficos
# distintos para cada valor ("Sim" ou "Nao")
sns.displot(data=df, binwidth=5, x='meses_contrato', col='cancelou_plano', hue='cancelou_plano')

# %% [markdown]
# Separando a fidelidade de clientes entre os que não cancelaram o plano e os que cancelaram o plano, é possível notar visualmente um dado muito importante: a maior quantidade de **clientes que estão cancelando o plano é formada por clientes novos**, sendo que um número muito considerável é formado por clientes de 0-5 meses de contrato.
#
# **Acima de 5 meses**, a quantidade de cancelamentos é bem **menor** e segue uma **curva decrescente**, à exceção de clientes entre 65 e 70 meses de contrato, que possui um leve crescimento.

# %% [markdown]
# Outra forma de verificar visualmente a quantidade de clientes que cancelou ou não o plano, baseado na quantidade de meses de contrato, é plotar as duas informações em um mesmo gráfico. No gráfico a seguir, os meses estão no eixo y, que eu imagino que facilite a visualização e comparação das proporções.

# %%
# multiple='fill' preenche 100% do gráfico e mostra a proporção ocupada pelas
# duas categorias de "cancelou_plano"
sns.displot(data=df, binwidth=5, y='meses_contrato', hue='cancelou_plano', multiple='fill')

# %% [markdown]
# Agora é possível visualizar que **mais da metade** das pessoas que possuem **até 5 meses** de contrato **cancelaram o plano**.

# %%
# calculando a proporção de clientes com até 5 meses de contrato que cancelaram ou não o plano
churn_5_months = df[df['meses_contrato'] <= 5]['cancelou_plano']
perc_churn_5_months_yes = round((churn_5_months == 'Sim').sum() / churn_5_months.count()*100, 2)
perc_churn_5_months_no = round((churn_5_months == 'Nao').sum() / churn_5_months.count()*100, 2)

print(f'{perc_churn_5_months_yes}% do clientes com até 5 meses de contrato cancelaram o plano.')
print(f'{perc_churn_5_months_no}% do clientes com até 5 meses de contrato mantiveram o plano.')
# Out:
# 54.27% do clientes com até 5 meses de contrato cancelaram o plano.
# 45.73% do clientes com até 5 meses de contrato mantiveram o plano.

# %% [markdown]
# Por fim, irei visualizar a proporção de clientes que cancelaram ou não o plano, para contratos de até 5 meses, separando mês a mês.

# %%
sns.displot(
    data=df[df['meses_contrato'] <= 5], 
    binwidth=1, 
    x='meses_contrato', 
    col='cancelou_plano', 
    hue='cancelou_plano')

# %% [markdown]
# É possível ver que boa parte dos cancelamentos acontece logo após o primeiro mês de contrato.
#
# ***Será que a empresa oferece algum tipo de "degustação" de um mês?*** Isso talvez explicasse por que tantos clientes cancelam o plano após o primeiro mês (que seria o "mês grátis"). É apenas uma suposição, a ser verificada com a empresa.

# %% [markdown]
# ### Conclusão
#
# Graficamente, é possível observar que a maior parte dos **cancelamentos** está **concentrada em clientes novos**, com até 5 meses de contrato, e que muitos deles estão cancelando o plano **logo após o primeiro mês** de contrato.

# %% [markdown]
# ## Churn X Outras variáveis categóricas
#
# Irei plotar mais alguns gráficos, relacionando o churn a outras variáveis categóricas, mas sem me aprofundar muito.

# %%
# lista com as variáveis categóricas que serão analisadas
cols = ['genero', 'possui_companheiro_companheira', 'possui_dependentes', 'plano_contratado']

# plotando os gráficos em sequência
# kind='count' faz a soma de resultados iguais, comportando-se como um histograma
for col in cols:
  # sns.displot(data=df, x=col, hue='cancelou_plano', multiple='dodge') #não está funcionando como eu queria
  sns.catplot(x='cancelou_plano', col=col, kind='count', data=df)

# %% [markdown]
# ### Conclusão
#
# Pode-se observar graficamente que **não parece haver diferença** no churn quando separado por **gênero**, embora [anteriormente foi possível constatar](#scrollTo=ggWQGYKYOOSe), também graficamente, que há uma concentração um pouco maior de mulheres que cancelaram planos na faixa dos planos mensais entre 70 e 90 dólares.
#
# Também é possível notar uma quantidade maior de pessoas que **cancelaram** os planos dentre aquelas que são **solteiras**, bem como dentre aquelas que **não possuem dependentes**.
#
# Dentre estes quatro gráficos, o que mais chama a atenção é o último, que mostra o churn rate separado entre os três contratos disponíveis: um ano, mensal e dois anos. A **grande maioria** dos cancelamentos é concentrada naqueles que possuem um **plano mensal**. É algo que faz sentido, visto que os outros dois planos podem não ser vantajosos para cancelamento (talvez possa haver alguma multa ou cláusula contratual que dificulte o cancelamento nestes casos, mas é apenas uma suposição minha).

# %% [markdown]
# # Análise da correlação entre as variáveis
#
# Para esta parte, contei com a ajuda dos links abaixo, pois ainda é um conteúdo que não sei quase nada. Infelizmente, pela falta de tempo e para entregar o projeto dentro do prazo do challenge, não irei me aprofundar nas teorias nem em entender mais a fundo o código (aka, essa seção tem bastante copy-paste...).
#
# **Encoding de variáveis categóricas:**
#
# https://pbpython.com/categorical-encoding.html
#
# https://www.askpython.com/python/examples/label-encoding
#
# **Correlação e heatmap:**
#
# https://medium.com/omixdata/estatística-análise-de-correlação-usando-python-e-r-d68611511b5a
#
# https://cursos.alura.com.br/course/estatistica-correlacao-regressao/task/57519

# %% [markdown]
# ## Label Encoding
#
# Para calcular a correlação, é necessário transformar os valores das variáveis categóricas em valores numéricos, pois a correlação é uma fórmula estatística, ou seja, trabalha com números.

# %%
# função que transforma os valores categóricos de uma coluna em valores numéricos
def label_encoding(categorical_col):
  # altera o tipo de "object" para o tipo "category"
  encode = categorical_col.astype('category')

  # atribui a cada categoria um valor numérico diferente
  return encode.cat.codes

# %%
# copiando a base de dados, para caso eu faça alguma coisa errada
df_copy = df.copy()

# %%
# listando as colunas categóricas
df_copy.select_dtypes(include=object).columns
# Out:
# Index(['cliente_ID', 'cancelou_plano', 'genero',
#        'possui_companheiro_companheira', 'possui_dependentes',
#        'assina_telefone', 'multiplas_linhas_telefonicas',
#        'tipo_assinatura_internet', 'adicional_seguranca_online',
#        'adicional_backup_online', 'adicional_protecao_dispositivo',
#        'adicional_suporte_VIP', 'assina_TV_cabo', 'assina_streaming_filmes',
#        'plano_contratado', 'fatura_online', 'forma_pagamento'],
#       dtype='object')

# %%
# retirei a coluna "cliente_ID", pois não irá fazer sentido o encode dela
cat_columns = ['cancelou_plano', 'genero', 'possui_companheiro_companheira', 
               'possui_dependentes', 'assina_telefone', 'multiplas_linhas_telefonicas',
               'tipo_assinatura_internet', 'adicional_seguranca_online',
               'adicional_backup_online', 'adicional_protecao_dispositivo',
               'adicional_suporte_VIP', 'assina_TV_cabo', 'assina_streaming_filmes',
               'plano_contratado', 'fatura_online', 'forma_pagamento']

# aplicando o label encoding
for col in cat_columns:
  # print(col)
  # print('Antes')
  # print(df_copy[col].unique())
  # print('Depois')
  df_copy[col] = label_encoding(df_copy[col])
  # print(df_copy[col].unique())
  # print('---')

# %%
# verificando o tipo das colunas
df_copy.dtypes
# Out:
# cliente_ID                         object
# cancelou_plano                       int8
# genero                               int8
# maior_65_anos                       int64
# possui_companheiro_companheira       int8
# possui_dependentes                   int8
# meses_contrato                      int64
# assina_telefone                      int8
# multiplas_linhas_telefonicas         int8
# tipo_assinatura_internet             int8
# adicional_seguranca_online           int8
# adicional_backup_online              int8
# adicional_protecao_dispositivo       int8
# adicional_suporte_VIP                int8
# assina_TV_cabo                       int8
# assina_streaming_filmes              int8
# plano_contratado                     int8
# fatura_online                        int8
# forma_pagamento                      int8
# gasto_diario                      float64
# gasto_mensal                      float64
# gasto_total                       float64
# dtype: object

# %% [markdown]
# ## Cálculo da correlação e Heatmap
# Com todas as colunas agora possuindo dados numéricos (menos a "cliente_ID"), podemos calcular a correlação, utilizando a fórmula já disponibilizada pelo Pandas, `corr()`, que, por padrão, calcula o coeficiente de Pearson entre cada par de colunas e retorna um DataFrame com a matriz de correlação.

# %%
# calculando a correlação
correlation = df_copy.corr()

# %%
# visualizando a matriz de correlação
# correlation #gera uma tabela bem grande; descomente se quiser ver

# %% [markdown]
# Para facilitar a visualização dos dados da matriz de correlação, pode-se utilizar a função `heatmap()` da biblioteca seaborn, que irá criar uma matriz colorida, em que a intensidade das cores informa visualmente a força da correção entre as variáveis.

# %%
# aumentando o tamanho da figura para facilitar a visualização
fig_dim = (20, 20)
fig, ax = plt.subplots(figsize=fig_dim)

# annot mostra o valor da correlação em cada célula;
# fmt formata os valores para um float com duas casas decimais;
# Para facilitar a interpretação da graduação das cores, vmin e vmax foram 
# deixados nos extremos da matriz de correlação ([1, -1])
sns.heatmap(correlation, annot=True, fmt='.2f', ax=ax, vmin=-1, vmax=1)

# salvando o heatmap em uma imagem
fig.savefig('heatmap.png')

# %% [markdown]
# Cores mais claras ou mais escuras no Heatmap indicam a força da correlação (cujo resultado é um valor entre 1 e -1). Conforme vão se aproximando dos extremos, a correlação aumenta, pois os valores vão se aproximando de [-1, 1].
#
# Visualmente, as cores predominantes estão entre roxo e vermelho, que são cores mais próximas do 0, o que indica que a **correlação entre as variáveis da base de dados é fraca ou nem mesmo possuem correlação**. Apesar disso, alguns cruzamentos se destacam, como a correlação entre "meses_contrato" e "gasto_total" (0.83, correlação forte), e entre as variáveis de gasto diário e mensal com relação ao total (0.65, correlação moderada).

# %% [markdown]
# Como o target é o Churn, vale a pena olhar os dados desta variável com as outras:

# %%
# correlações para a variável de churn
correlation['cancelou_plano']
# Out:
# cancelou_plano                    1.000000
# genero                            0.008612
# maior_65_anos                     0.150889
# possui_companheiro_companheira   -0.150448
# possui_dependentes               -0.164221
# meses_contrato                   -0.352229
# assina_telefone                   0.011942
# multiplas_linhas_telefonicas      0.038037
# tipo_assinatura_internet         -0.047291
# adicional_seguranca_online       -0.289309
# adicional_backup_online          -0.195525
# adicional_protecao_dispositivo   -0.178134
# adicional_suporte_VIP            -0.282492
# assina_TV_cabo                   -0.036581
# assina_streaming_filmes          -0.038492
# plano_contratado                  0.084919
# fatura_online                     0.191825
# forma_pagamento                  -0.076433
# gasto_diario                      0.193412
# gasto_mensal                      0.193356
# gasto_total                      -0.198347
# Name: cancelou_plano, dtype: float64

# %% [markdown]
# É possível observar que a única correlação possível de identificar é da variável de **churn com a "meses_contrato"**, mas que ainda assim é uma **correlação fraca**, de -0,35.
#
# O **restante** dos valores ficou abaixo de 0.3 (positivo ou negativo), o que indica que **não há correlação**.
#
# Lembrando que anteriormente foi feita uma [análise gráfica de churn e gastos mensais](#scrollTo=7mBqkTa_FjO9).

# %% [markdown]
# # TO DO
#
# Infelizmente, algumas atividades ficaram incompletas, outras nem pude fazer. Fica aqui uma lista de algumas das coisas que ficaram faltando:
#
# 1. Dar nomes aos gráficos, eixos e legendas
# 2. Utilizar o Plotly para gráficos diferentes e interativos
# 3. Verificar relacionamento entre variáveis, sem necessariamente incluir o churn.
